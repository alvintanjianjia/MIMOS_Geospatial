# %%
import geopandas as gp
import geohash
import pandas as pd
import numpy as np
import fiona
import json
import shapely
import shapely.geometry
from osgeo import ogr
import requests
import psycopg2
from sqlalchemy import create_engine
import psycopg2
from sqlalchemy import create_engine

# %%
selangor_poi = gp.GeoDataFrame.from_file('D:\Datasets\GeoSpatial\selangor_data/selangor_poi.shp')
selangor_poi.head()
# Out:
#      osm_id  code       fclass               name GID_0    NAME_0     GID_1  \
# 0  19206023  2501  supermarket              Giant   MYS  Malaysia  MYS.15_1
# 1  19206050  2501  supermarket              Mydin   MYS  Malaysia  MYS.15_1
# 2  19207507  2501  supermarket        Tesco Extra   MYS  Malaysia  MYS.15_1
# 3  19207509  2256      stadium   Stadium Malawati   MYS  Malaysia  MYS.15_1
# 4  19207529  2256      stadium  Stadium Shah Alam   MYS  Malaysia  MYS.15_1
#
#      NAME_1             VARNAME_1 NL_NAME_1  TYPE_1 ENGTYPE_1  CC_1 HASC_1  \
# 0  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
# 1  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
# 2  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
# 3  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
# 4  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
#
#                                             geometry
# ...

# %%
## Getting the centroid coordinates for lat lon

selangor_poi['lat'] = selangor_poi['geometry'].centroid.y
selangor_poi['lon'] = selangor_poi['geometry'].centroid.x

# %%
selangor_poi.head()
# Out:
#      osm_id  code       fclass               name GID_0    NAME_0     GID_1  \
# 0  19206023  2501  supermarket              Giant   MYS  Malaysia  MYS.15_1
# 1  19206050  2501  supermarket              Mydin   MYS  Malaysia  MYS.15_1
# 2  19207507  2501  supermarket        Tesco Extra   MYS  Malaysia  MYS.15_1
# 3  19207509  2256      stadium   Stadium Malawati   MYS  Malaysia  MYS.15_1
# 4  19207529  2256      stadium  Stadium Shah Alam   MYS  Malaysia  MYS.15_1
#
#      NAME_1             VARNAME_1 NL_NAME_1  TYPE_1 ENGTYPE_1  CC_1 HASC_1  \
# 0  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
# 1  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
# 2  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
# 3  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
# 4  Selangor  Selangor Darul Ehsan      None  Negeri     State  None  MY.SL
#
# ...

# %%
selangor_poi.to_csv('D:\Datasets\GeoSpatial\selangor_data/selangor_poi.csv', index=False)
