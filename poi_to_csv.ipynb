# %%
import geopandas as gp
import geohash
import pandas as pd
import numpy as np
import fiona
import json
import shapely
import shapely.geometry
from osgeo import ogr
import requests
import psycopg2
from sqlalchemy import create_engine
import psycopg2
from sqlalchemy import create_engine

# %%
selangor_poi = gp.GeoDataFrame.from_file('D:\Datasets\MIMOS\kl_selangor_poi/kl_selangor_poi.shp')
selangor_poi.head()
# Out:
#       osm_id  code       fclass                                 name GID_0  \
# 0  158731933  2501  supermarket                                 Hero   MYS
# 1  158732943  2504         mall                              Ole Ole   MYS
# 2  158741219  2302    fast_food                           McDonald's   MYS
# 3  168928764  2110     hospital  SALAM Shah Alam Specialist Hospital   MYS
# 4  168931187  2301   restaurant                           Seri Bunga   MYS
#
#      NAME_0     GID_1    NAME_1             VARNAME_1 NL_NAME_1  TYPE_1  \
# 0  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
# 1  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
# 2  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
# 3  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
# 4  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
#
#   ENGTYPE_1  CC_1 HASC_1                        geometry
# ...

# %%
## Getting the centroid coordinates for lat lon

selangor_poi['lat'] = selangor_poi['geometry'].centroid.y
selangor_poi['lon'] = selangor_poi['geometry'].centroid.x

# %%
selangor_poi.head()
# Out:
#       osm_id  code       fclass                                 name GID_0  \
# 0  158731933  2501  supermarket                                 Hero   MYS
# 1  158732943  2504         mall                              Ole Ole   MYS
# 2  158741219  2302    fast_food                           McDonald's   MYS
# 3  168928764  2110     hospital  SALAM Shah Alam Specialist Hospital   MYS
# 4  168931187  2301   restaurant                           Seri Bunga   MYS
#
#      NAME_0     GID_1    NAME_1             VARNAME_1 NL_NAME_1  TYPE_1  \
# 0  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
# 1  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
# 2  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
# 3  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
# 4  Malaysia  MYS.15_1  Selangor  Selangor Darul Ehsan      None  Negeri
#
#   ENGTYPE_1  CC_1 HASC_1                        geometry       lat         lon
# ...

# %%
selangor_poi.to_csv('D:\Datasets\MIMOS\kl_selangor_poi.csv', index=False)
